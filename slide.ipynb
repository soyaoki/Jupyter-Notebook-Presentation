# %% [markdown]
# # Test!!
#
# ## This is a test for presentation on Jupyter Notebook

# %% [markdown]
# ### Does this work well?

# %%
while():
    print('P')
    print('D')
    print('C')
    print('A')
# Out:
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# C
# A
# P
# D
# ...
